# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Uber-Jan-Feb-FOIL.csv')

# %%
df.head()
# Out:
#   dispatching_base_number      date  active_vehicles  trips
# 0                  B02512  1/1/2015              190   1132
# 1                  B02765  1/1/2015              225   1765
# 2                  B02764  1/1/2015             3427  29421
# 3                  B02682  1/1/2015              945   7679
# 4                  B02617  1/1/2015             1228   9537

# %%
df.dtypes
# Out:
# dispatching_base_number    object
# date                       object
# active_vehicles             int64
# trips                       int64
# dtype: object

# %%
data = df['date']

# Splitting the 'date' column
df[['Month', 'Day', 'Year']] = df['date'].str.split('/', expand=True)

df
# Out:
#     dispatching_base_number       date  active_vehicles  trips Month Day  Year
# 0                    B02512   1/1/2015              190   1132     1   1  2015
# 1                    B02765   1/1/2015              225   1765     1   1  2015
# 2                    B02764   1/1/2015             3427  29421     1   1  2015
# 3                    B02682   1/1/2015              945   7679     1   1  2015
# 4                    B02617   1/1/2015             1228   9537     1   1  2015
# ..                      ...        ...              ...    ...   ...  ..   ...
# 349                  B02764  2/28/2015             3952  39812     2  28  2015
# 350                  B02617  2/28/2015             1372  14022     2  28  2015
# 351                  B02682  2/28/2015             1386  14472     2  28  2015
# 352                  B02512  2/28/2015              230   1803     2  28  2015
# 353                  B02765  2/28/2015              747   7753     2  28  2015
#
# [354 rows x 7 columns]

# %%
df=df.drop('date',axis=1)

# %%
df.head()
# Out:
#   dispatching_base_number  active_vehicles  trips Month Day  Year
# 0                  B02512              190   1132     1   1  2015
# 1                  B02765              225   1765     1   1  2015
# 2                  B02764             3427  29421     1   1  2015
# 3                  B02682              945   7679     1   1  2015
# 4                  B02617             1228   9537     1   1  2015

# %%
df.dtypes
# Out:
# dispatching_base_number    object
# active_vehicles             int64
# trips                       int64
# Month                      object
# Day                        object
# Year                       object
# dtype: object

# %%
df['Month']=df['Month'].astype(int)

# %%
df['Month'].dtypes
# Out:
# dtype('int32')

# %%
df['Day']=df['Day'].astype(int)
df['Year']=df['Year'].astype(int)

# %%
df.dtypes
# Out:
# dispatching_base_number    object
# active_vehicles             int64
# trips                       int64
# Month                       int32
# Day                         int32
# Year                        int32
# dtype: object

# %%
sns.barplot(data=df,x='dispatching_base_number',y='trips',hue='Month');

# %%
sns.pairplot(df);
# Out:
# C:\Users\GREESHMA\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
